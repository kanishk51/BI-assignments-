# %% [markdown]
# <a href="https://colab.research.google.com/github/kanishk51/BI-assignments-/blob/main/Assignment6_202301028_03april.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# Read data from CSV file

df = pandas.read_csv("test9.csv")

# Extract CPU and GPU values
x = list(df['CPU'])
y = list(df["GPU"])
data = list(zip(x, y))

kmeans = KMeans(n_clusters=2)  # Change the number of clusters as needed
kmeans.fit(data)
# df['Cluster'] = kmeans.labels_

# Visualize the clusters
plt.scatter(x, y, c=kmeans.labels_)
plt.xlabel('CPU')
plt.ylabel('GPU')
plt.title('K-Means Clustering')

plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
import pandas
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# Read data from CSV file

df = pandas.read_csv("test9.csv")

# Extract CPU and GPU values
x = list(df['CPU'])
y = list(df["GPU"])
data = list(zip(x, y))

kmeans = KMeans(n_clusters=3)  # Change the number of clusters as needed
kmeans.fit(data)
# df['Cluster'] = kmeans.labels_

# Visualize the clusters
plt.scatter(x, y, c=kmeans.labels_)
plt.xlabel('CPU')
plt.ylabel('GPU')
plt.title('K-Means Clustering')

plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
import pandas
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# Read data from CSV file

df = pandas.read_csv("test9.csv")

# Extract CPU and GPU values
x = list(df['CPU'])
y = list(df["GPU"])
data = list(zip(x, y))

kmeans = KMeans(n_clusters=4)  # Change the number of clusters as needed
kmeans.fit(data)
# df['Cluster'] = kmeans.labels_

# Visualize the clusters
plt.scatter(x, y, c=kmeans.labels_)
plt.xlabel('CPU')
plt.ylabel('GPU')
plt.title('K-Means Clustering')

plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
